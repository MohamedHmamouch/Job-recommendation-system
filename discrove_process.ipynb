# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Discovering data

# %%
raw_data=pd.read_csv('survey_results_public.csv')
print('my public survey has {} in shape'.format(raw_data.shape))
# Out:
# my public survey has (83439, 48) in shape

# %%
raw_data.sample(20)
# Out:
#        ResponseId                      MainBranch  \
# 50597       50598  I am a developer by profession
# 5435         5436  I am a developer by profession
# 65630       65631  I am a developer by profession
# 65803       65804  I am a developer by profession
# 32584       32585  I am a developer by profession
# 35347       35348  I am a developer by profession
# 25320       25321  I am a developer by profession
# 30819       30820     I code primarily as a hobby
# 33737       33738  I am a developer by profession
# 21672       21673  I am a developer by profession
# 27272       27273  I am a developer by profession
# 3594         3595  I am a developer by profession
# 65171       65172  I am a developer by profession
# 3093         3094  I am a developer by profession
# 44848       44849  I am a developer by profession
# 25962       25963  I am a developer by profession
# 17865       17866  I am a developer by profession
# 56440       56441  I am a developer by profession
# 17360       17361  I am a developer by profession
# 53135       53136  I am a developer by profession
#
#                                               Employment  \
# 50597                                 Employed full-time
# 5435   Independent contractor, freelancer, or self-em...
# 65630                                 Employed part-time
# 65803                                 Employed full-time
# 32584                                 Employed full-time
# 35347                                 Employed full-time
# 25320                                 Employed full-time
# 30819                 Not employed, but looking for work
# 33737  Independent contractor, freelancer, or self-em...
# 21672                                 Employed full-time
# 27272                                 Employed full-time
# 3594                                  Employed full-time
# 65171                                 Employed full-time
# 3093                                  Employed full-time
# 44848                                 Employed full-time
# 25962                                 Employed full-time
# 17865  Independent contractor, freelancer, or self-em...
# 56440                                 Employed full-time
# 17360                                 Employed full-time
# 53135                                 Employed full-time
#
#                                                  Country       US_State  \
# 50597                           United States of America       Virginia
# 5435                        Iran, Islamic Republic of...            NaN
# 65630                                             Brazil            NaN
# 65803                           United States of America       Missouri
# 32584                                             Sweden            NaN
# 35347                                             Jordan            NaN
# 25320                                             Mexico            NaN
# 30819                                             Canada            NaN
# 33737                           United States of America  Massachusetts
# 21672                           United States of America     California
# 27272                                              India            NaN
# 3594                                              Sweden            NaN
# 65171                                           Slovenia            NaN
# 3093   United Kingdom of Great Britain and Northern I...            NaN
# 44848                                           Thailand            NaN
# 25962                                              Italy            NaN
# 17865                                Republic of Moldova            NaN
# 56440                                             France            NaN
# 17360                                       Saudi Arabia            NaN
# 53135                           United States of America      Tennessee
#
#       UK_Country                                            EdLevel  \
# 50597        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5435         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65630        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65803        NaN                Associate degree (A.A., A.S., etc.)
# 32584        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 35347        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 25320        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 30819        NaN  Some college/university study without earning ...
# 33737        NaN         Other doctoral degree (Ph.D., Ed.D., etc.)
# 21672        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 27272        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3594         NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65171        NaN  Some college/university study without earning ...
# 3093     England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 44848        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 25962        NaN  Some college/university study without earning ...
# 17865        NaN  Some college/university study without earning ...
# 56440        NaN  Some college/university study without earning ...
# 17360        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 53135        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#           Age1stCode                                          LearnCode  \
# 50597  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 5435   11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 65630  18 - 24 years                            Other (please specify):
# 65803  11 - 17 years  School;Online Courses or Certification;Books /...
# 32584  11 - 17 years  School;Online Forum;Friend or family member;On...
# 35347   5 - 10 years  School;Friend or family member;Online Courses ...
# 25320  11 - 17 years  School;Online Forum;Friend or family member;On...
# 30819   5 - 10 years  Other online resources (ex: videos, blogs, etc...
#
# 30819            None of the above
# 33737            None of the above
# 21672            None of the above
# 27272            None of the above
# 3594             None of the above
# 65171            None of the above
# 3093             None of the above
# 44848            None of the above
# 25962            None of the above
# 17865            None of the above
# 56440            None of the above
# 17360            None of the above
# 53135            None of the above
#
#                                             MentalHealth  \
# 50597                                                NaN
# 5435                                   None of the above
# 65630                                  None of the above
# 65803                                  None of the above
# 32584                                  None of the above
# 35347                                  None of the above
# 25320  I have a concentration and/or memory disorder ...
# 30819                                  None of the above
# 33737                                  None of the above
# 21672                                  None of the above
# 27272                                  Prefer not to say
# 3594                                   None of the above
# 65171                                  None of the above
# 3093                                   None of the above
# 44848                                  None of the above
# 25962                                  None of the above
# 17865                                  None of the above
# 56440  I have a mood or emotional disorder (e.g. depr...
# 17360                                  None of the above
# 53135                         I have an anxiety disorder
#
#                 SurveyLength                  SurveyEase ConvertedCompYearly
# 50597  Appropriate in length                        Easy             80000.0
# 5435   Appropriate in length                        Easy                 NaN
# 65630  Appropriate in length                        Easy              4128.0
# 65803  Appropriate in length                        Easy            138000.0
# 32584                    NaN                        Easy             62964.0
# 35347  Appropriate in length                        Easy                 NaN
# 25320  Appropriate in length                        Easy                 NaN
# 30819  Appropriate in length  Neither easy nor difficult                 NaN
# 33737  Appropriate in length                        Easy                 NaN
# 21672  Appropriate in length                        Easy             70000.0
# 27272               Too long  Neither easy nor difficult              8376.0
# 3594                     NaN                        Easy             55224.0
# 65171  Appropriate in length                        Easy             64860.0
# 3093   Appropriate in length                        Easy             51704.0
# 44848  Appropriate in length                        Easy             17292.0
# 25962  Appropriate in length                        Easy                 NaN
# 17865  Appropriate in length                        Easy            108000.0
# 56440  Appropriate in length  Neither easy nor difficult             59454.0
# 17360  Appropriate in length                        Easy             79980.0
# 53135  Appropriate in length                        Easy            165000.0
#
# [20 rows x 48 columns]

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
#  12  OrgSize                       60726 non-null  object
#  13  Currency                      61080 non-null  object
#  14  CompTotal                     47183 non-null  float64
#  15  CompFreq                      52150 non-null  object
#  16  LanguageHaveWorkedWith        82357 non-null  object
#  17  LanguageWantToWorkWith        76821 non-null  object
#  18  DatabaseHaveWorkedWith        69546 non-null  object
#  19  DatabaseWantToWorkWith        58299 non-null  object
#  20  PlatformHaveWorkedWith        52135 non-null  object
#  21  PlatformWantToWorkWith        41619 non-null  object
#  22  WebframeHaveWorkedWith        61707 non-null  object
#  23  WebframeWantToWorkWith        52095 non-null  object
#  24  MiscTechHaveWorkedWith        47055 non-null  object
#  25  MiscTechWantToWorkWith        38021 non-null  object
#  26  ToolsTechHaveWorkedWith       72537 non-null  object
#  27  ToolsTechWantToWorkWith       65480 non-null  object
#  28  NEWCollabToolsHaveWorkedWith  81234 non-null  object
#  29  NEWCollabToolsWantToWorkWith  73022 non-null  object
#  30  OpSys                         83294 non-null  object
#  31  NEWStuck                      83052 non-null  object
#  32  NEWSOSites                    83171 non-null  object
#  33  SOVisitFreq                   82413 non-null  object
#  34  SOAccount                     82525 non-null  object
#  35  SOPartFreq                    67553 non-null  object
#  36  SOComm                        82319 non-null  object
#  37  NEWOtherComms                 82828 non-null  object
#  38  Age                           82407 non-null  object
#  39  Gender                        82286 non-null  object
#  40  Trans                         80678 non-null  object
#  41  Sexuality                     73366 non-null  object
#  42  Ethnicity                     79464 non-null  object
#  43  Accessibility                 77603 non-null  object
#  44  MentalHealth                  76920 non-null  object
#  45  SurveyLength                  81711 non-null  object
#  46  SurveyEase                    81948 non-null  object
#  47  ConvertedCompYearly           46844 non-null  float64
# dtypes: float64(2), int64(1), object(45)
# memory usage: 30.6+ MB

# %%
raw_data.sample(1).iloc[0]
# Out:
# ResponseId                                                                  57443
# MainBranch                                         I am a developer by profession
# Employment                                                     Employed full-time
# Country                                                  United States of America
# US_State                                                                     Utah
# UK_Country                                                                    NaN
# EdLevel                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Age1stCode                                                           5 - 10 years
# LearnCode                                           School;Books / Physical media
# YearsCode                                                                      40
# YearsCodePro                                                                   24
# DevType                         Developer, front-end;Developer, desktop or ent...
# OrgSize                                                        20 to 99 employees
# Currency                                                USD\tUnited States dollar
# CompTotal                                                                190000.0
# CompFreq                                                                   Yearly
# LanguageHaveWorkedWith                      C#;HTML/CSS;JavaScript;PowerShell;SQL
# LanguageWantToWorkWith                     C#;F#;HTML/CSS;Python;R;SQL;TypeScript
# DatabaseHaveWorkedWith                                 Microsoft SQL Server;Redis
# DatabaseWantToWorkWith                 Elasticsearch;Microsoft SQL Server;MongoDB
# PlatformHaveWorkedWith                                            Microsoft Azure
# PlatformWantToWorkWith                                            Microsoft Azure
# WebframeHaveWorkedWith                                       ASP.NET Core ;jQuery
# WebframeWantToWorkWith                              ASP.NET Core ;React.js;Vue.js
# MiscTechHaveWorkedWith                          .NET Framework;.NET Core / .NET 5
# MiscTechWantToWorkWith                 .NET Core / .NET 5;React Native;TensorFlow
# ToolsTechHaveWorkedWith                                                Docker;Git
# ToolsTechWantToWorkWith                                           Docker;Git;Yarn
# NEWCollabToolsHaveWorkedWith    Atom;Notepad++;Rider;Sublime Text;Visual Studi...
# NEWCollabToolsWantToWorkWith               Rider;Visual Studio;Visual Studio Code
# OpSys                                                                       MacOS
# NEWStuck                        Visit Stack Overflow;Go for a walk or other ph...
# NEWSOSites                                          Stack Overflow;Stack Exchange
# SOVisitFreq                                       A few times per month or weekly
# SOAccount                                                                     Yes
# SOPartFreq                                    Less than once per month or monthly
# SOComm                                                              Yes, somewhat
# NEWOtherComms                                                                  No
# Age                                                               45-54 years old
# Gender                                                                        Man
# Trans                                                                          No
# Sexuality                                                 Straight / Heterosexual
# Ethnicity                                            White or of European descent
# Accessibility                                                   None of the above
# MentalHealth                    I have a concentration and/or memory disorder ...
# SurveyLength                                                            Too short
# SurveyEase                                                                   Easy
# ConvertedCompYearly                                                      190000.0
# Name: 57442, dtype: object

# %% [markdown]
# ### Remarks:
# - All our columns are object, <strong>weird!!</strong>

# %%
raw_data.describe()
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
# i can notice that, basicaly we need Age,Age1stCode, LearnCode,YearsCode columns to be numerical
# why they are object

#let's see why 
should_be_num=['Age1stCode','YearsCode','Age','YearsCodePro']

for i in should_be_num:
    print(i)
    print(raw_data[i].unique().tolist())
    print('----------------')
# Out:
# Age1stCode
# ['18 - 24 years', '11 - 17 years', '5 - 10 years', '25 - 34 years', '35 - 44 years', 'Younger than 5 years', '45 - 54 years', '55 - 64 years', nan, 'Older than 64 years']
# ----------------
# YearsCode
# [nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9', '26', '14', '39', '20', '8', '19', '5', 'Less than 1 year', '22', '2', '1', '34', '21', '13', '25', '24', '30', '31', '18', '38', 'More than 50 years', '27', '41', '42', '35', '23', '28', '11', '37', '44', '43', '36', '33', '45', '29', '50', '46', '32', '47', '49', '48']
# ----------------
# Age
# ['25-34 years old', '18-24 years old', '35-44 years old', 'Prefer not to say', '45-54 years old', 'Under 18 years old', '65 years or older', '55-64 years old', nan]
# ----------------
# YearsCodePro
# [nan, '10', '4', '5', '6', '2', '30', '9', '18', '12', '21', '1', '16', 'Less than 1 year', '15', '3', '35', '7', '8', '17', '14', '26', '25', '20', '50', '34', '11', '24', '22', '13', '31', '23', '39', '41', '27', '28', '19', '33', 'More than 50 years', '37', '29', '32', '43', '40', '38', '45', '42', '46', '36', '44', '47', '48', '49']
# ----------------
